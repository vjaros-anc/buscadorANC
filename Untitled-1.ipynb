# %% [markdown]
# # Merge  firm (certero, 2024-hoy)  +  firm3 (extracción Python)  →  firm4
#
# - **firm** manda: sus Mercados/Decisión/fechas son la verdad; donde esté vacío se completa con firm3.
# - **firm3** aporta Empresas involucradas / Grupo y las columnas V2 (mercado/relaciones extraídos, referenciales).
# - Se une por **clave TIPO-NÚMERO** (CONC-1951), robusta a `(PROSUM)`, puntos y espacios duros — NO por Nº de Resolución (que es NaN en PROSUM/OPI y hacía explotar el merge a 2217 filas).
# - firm3 se **consolida**: un expediente = una fila (junta versiones CONC-1010 + CONC-1010_2).

# %%
import re, json
import numpy as np
import pandas as pd

# %%
firm = pd.read_excel(r"C:\Users\Admin\Documents\GitHub\buscadorANC\firm.xlsx",   sheet_name="firmadas")
dfs  = pd.read_excel(r"C:\Users\Admin\Documents\GitHub\buscadorANC\firm3_.xlsx", sheet_name="firmadas")
firm.columns = firm.columns.str.strip()
dfs.columns  = dfs.columns.str.strip()

# %% [markdown]
# ## Clave robusta TIPO-NÚMERO (ignora PROSUM / puntos / espacios duros)

# %%
def clave(s):
    if pd.isna(s):
        return None
    m = re.search(r"(CONC|OPI|DP|INC)\D*(\d{3,4})", str(s).upper())
    return f"{m.group(1)}-{m.group(2)}" if m else None

firm["_k"] = firm["Carpeta"].map(clave)
dfs["_k"]  = dfs["Carpeta"].map(clave)

# %%
# firm3 aporta el mercado/relaciones extraídos como columnas V2 (referenciales)
dfs = dfs.rename(columns={"Mercados relevantes":   "mercado_relev_V2",
                          "Relaciones económicas": "relaciones_econ_V2"})

# %% [markdown]
# ## Consolidar firm3: un expediente = una fila (junta CONC-1010 + CONC-1010_2)

# %%
def _first(s):
    s = s.dropna()
    return s.iloc[0] if len(s) else np.nan

def _union_emp(s):
    """une las listas JSON de empresas de las versiones, sin duplicar."""
    arr, vistos, out = [], set(), []
    for v in s.dropna():
        try:
            arr += json.loads(v)
        except Exception:
            pass
    for e in arr:
        k = (e.get("rol"), (e.get("nombre") or "").strip().lower())
        if k[1] and k not in vistos:
            vistos.add(k); out.append(e)
    return json.dumps(out, ensure_ascii=False) if out else np.nan

agg = {c: (_union_emp if c == "Empresas involucradas" else _first)
       for c in dfs.columns if c != "_k"}
dfs_c = dfs[dfs["_k"].notna()].groupby("_k", as_index=False).agg(agg)
print("firm3:", len(dfs), "-> consolidado por clave:", len(dfs_c))
# Out:
# firm3: 932 -> consolidado por clave: 898

# %% [markdown]
# ## Merge: firm manda; se completan SÓLO sus faltantes con firm3

# %%
firm4 = firm.merge(dfs_c, on="_k", how="left", suffixes=("", "_f3"))

# completar SÓLO faltantes de firm con el dato de firm3 (firm manda)
fill_desde = {
    "Mercados relevantes":   "mercado_relev_V2",
    "Relaciones económicas": "relaciones_econ_V2",
    "Decisión":              "Decisión_f3",
    "Fecha_Ingreso":         "Fecha_Ingreso_f3",
    "Fecha_firma":           "Fecha_firma_f3",
    "Número de Dictamen":    "Número de Dictamen_f3",
    "Carátula":              "Carátula_f3",
    "Excluible":             "Excluible_f3",
    "tipo":                  "tipo_f3",
}
for base, src in fill_desde.items():
    if base in firm4 and src in firm4:
        firm4[base] = firm4[base].where(firm4[base].notna(), firm4[src])

# descartar columnas auxiliares _f3
firm4 = firm4.drop(columns=[c for c in firm4.columns if c.endswith("_f3")])

# agregar filas de firm3 que firm NO cubre (pre-2024 y no matcheadas)
faltan = dfs_c[~dfs_c["_k"].isin(firm["_k"].dropna())].copy()
firm4 = pd.concat([firm4, faltan], ignore_index=True)

# %%
# limpieza final
firm4 = firm4.dropna(subset=["Carpeta"])
firm4 = firm4.drop_duplicates()          # saca filas 100% idénticas (duplicados propios de firm)
firm4 = firm4.drop(columns=["_k"])

# chequeo rápido: no debe explotar ni repetir carpetas de más
print("filas firm4:", len(firm4))
_d = firm4["Carpeta"].map(clave).dropna().value_counts()
_d = _d[_d > 1]
print("carpetas duplicadas (vienen de firm, revisar a mano):", dict(list(_d.items())))
firm4
# Out:
# filas firm4: 932
# carpetas duplicadas (vienen de firm, revisar a mano): {'INC-1663': 4}
#      tipo    Carpeta Excluible  \
# 0    CONC  CONC 1884       NaN
# 1    CONC  CONC 1913       NaN
# 2    CONC  CONC 1905       NaN
# 3    CONC  CONC 1846       NaN
# 4    CONC  CONC 1915       NaN
# ..    ...        ...       ...
# 984  CONC   CONC-977       NaN
# 985  CONC   CONC-982       NaN
# 986  CONC   CONC-990       NaN
# 987  CONC   CONC-996       NaN
# 988  CONC   CONC-997       NaN
#
#                                               Carátula        Fecha_Ingreso  \
# 0    LOS LAPACHOS S.A. S/ NOTIFICACION ART. 9 DE LA...  2022-12-12 00:00:00
# 1     YPF S.A. S/NOTIFICACION ART. 9 DE LA LEY 27.442.  2023-05-08 00:00:00
# 2    PETROLERA ACONCAGUA ENERGIA S.A. S/ NOTIFICACI...  2023-03-08 00:00:00
# 3    PACKAGING INVESTMENTS HOLDINGS (PIH) B.V. Y PA...  2022-04-06 00:00:00
# 4    TOTAL AUSTRAL S.A. -SUCURSAL ARGENTINA- S/NOTI...  2023-05-08 00:00:00
# ..                                                 ...                  ...
# 984                                                NaN                  NaT
# 985                                                NaN                  NaT
# 986  EMGASUD S.A., EMGASUD RENOVABLES S.A., FIDES G...                  NaT
# 987                                                NaN                  NaT
# 988  GLENCORE INTERNATIONAL PLC y XSTRATA PLC S/NOT...  2012-05-02 00:00:00
#
#     Fecha_firma                       Decisión        Número de Resolución  \
# 0    2024-02-15  Autoriza Art.14 a) Ley 27.442    RESOL-2024-64-APN-SC#MEC
# 1    2024-02-19  Autoriza Art.14 a) Ley 27.442    RESOL-2024-67-APN-SC#MEC
# 2    2024-02-19  Autoriza Art.14 a) Ley 27.442    RESOL-2024-69-APN-SC#MEC
# 3    2024-02-19  Autoriza Art.14 a) Ley 27.442    RESOL-2024-68-APN-SC#MEC
# 4    2024-02-19  Autoriza Art.14 a) Ley 27.442    RESOL-2024-66-APN-SC#MEC
# ..          ...                            ...                         ...
# 984  2016-12-07                            NaN   RESOL-2017-52-APN-SECC#MP
# 985  2017-04-04                            NaN  RESOL-2017-280-APN-SECC#MP
# 986  2017-12-14  Autoriza Art.13 a) Ley 25.156   RESOL-2018-64-APN-SECC#MP
# 987  2017-04-11  Autoriza Art.13 a) Ley 25.156  RESOL-2017-374-APN-SECC#MP
# 988         NaT  Autoriza Art.13 a) Ley 25.156  RESOL-2018-152-APN-SECC#MP
#
#                 Número de Dictamen  \
# 0    IF-2024-12165053-APN-CNDC#MEC
# 1    IF-2024-13965157-APN-CNDC#MEC
# 2    IF-2024-12167822-APN-CNDC#MEC
# 3    IF-2024-13968582-APN-CNDC#MEC
# 4    IF-2024-13969597-APN-CNDC#MEC
# ..                             ...
# 984   IF-2016-04271662-APN-CNDC#MP
# 985   IF-2017-05259651-APN-CNDC#MP
# 986   IF-2017-32919258-APN-CNDC#MP
# 987   IF-2017-06231935-APN-CNDC#MP
# 988   IF-2018-06640834-APN-CNDC#MP
#
#                                    Mercados relevantes  \
# 0    servicio de emisión de tarjetas de crédito y s...
# 1    Exploración y producción de petróleo y gas nat...
# 2    Exploración y explotación de petróleo y gas na...
# 3    Pproducción y comercialización de envases de c...
# 4    Exploración y explotación de petróleo y gas na...
# ..                                                 ...
# 984                                                NaN
# 985                                                NaN
# 986                                                NaN
# 987                                                NaN
# 988                                                NaN
#
#          Relaciones económicas  meses  DIAS  \
# 0                     Vertical    NaN   NaN
# 1    Horizontales y verticales    NaN   NaN
# 2    Horizontales y verticales    NaN   NaN
# 3    Horizontales y verticales    NaN   NaN
# 4    Horizontales y verticales    NaN   NaN
# ..                         ...    ...   ...
# 984                        NaN    NaN   NaN
# 985                        NaN    NaN   NaN
# 986                        NaN    NaN   NaN
# 987                        NaN    NaN   NaN
# 988                        NaN    NaN   NaN
#
#                                          Grupo/Empresa  \
# 0                                    LOS LAPACHOS S.A.
# 1                                             YPF S.A.
# 2                     PETROLERA ACONCAGUA ENERGIA S.A.
# 3    PACKAGING INVESTMENTS HOLDINGS (PIH) B.V. Y PA...
# 4              TOTAL AUSTRAL S.A. -SUCURSAL ARGENTINA-
# ..                                                 ...
# 984                                                NaN
# 985  NEC CORPORATION a la firma CORPORACIÓN PARA LA...
# 986             EMGASUD S.A. y EMGASUD RENOVABLES S.A.
# 987                                                NaN
# 988           GLENCORE INTERNATIONAL PLC y XSTRATA PLC
#
#                                  Empresas involucradas  \
# 0                                                  NaN
# 1    [{"rol": "comprador", "nombre": "COMPAÑIAS DE ...
# 2    [{"rol": "comprador", "nombre": "PAESA"}, {"ro...
# 3    [{"rol": "objeto", "nombre": "ARGENCRAFT"}, {"...
# 4    [{"rol": "objeto", "nombre": "EREN SERVICES AR...
# ..                                                 ...
# 984                                                NaN
# 985                                                NaN
# 986  [{"rol": null, "nombre": "EMGASUD RENOVABLES S...
# 987                                                NaN
# 988  [{"rol": "comprador", "nombre": "ADVANCED ORGA...
#
#                                       mercado_relev_V2     relaciones_econ_V2
# 0                                                  NaN               Vertical
# 1                                                  NaN  Horizontal + vertical
# 2                                                  NaN  Horizontal + vertical
# 3    comercialización de envases de cartón corrugad...  Horizontal + vertical
# 4    Exploración y explotación de petróleo y gas. C...  Horizontal + vertical
# ..                                                 ...                    ...
# 984                                                NaN                    NaN
# 985                                                NaN                    NaN
# 986                                                NaN                    NaN
# 987                                                NaN                    NaN
# 988  Proyecto Relincho, en la provincia de San Juan...           Conglomerado
#
# [932 rows x 17 columns]

# %%
firm4.to_excel("firm4.xlsx", index=False)

# %% [markdown]
# ---
# **Antes de correr:** regenerar `firm3_.xlsx` con el extractor (`python extraer_firmadas3.py` → renombrar la salida a `firm3_.xlsx`) para que traiga las empresas del FIX 7. Cerrá `firm4.xlsx` en Excel antes de escribir.
#
# _Nota:_ las carpetas que quedan duplicadas provienen de duplicados propios de `firm.xlsx` (ej. `INC-1663`, `CONC-1951 (PROSUM)` cargados 2 veces) y filas basura como `"12"` — conviene limpiarlas en el archivo certero.

# %%
# (referencia) carga multi-año original, por si hay que reconstruir firm3 desde los res_firmadas_<año>.xlsx:
# dfs = {}
# for i in range(2026, 2017, -1):
#     dfs[i] = pd.read_excel(f"C:\\Users\\Admin\\Documents\\ANC\\descargas_cndc\\res_firmadas_{i}.xlsx", sheet_name="firmadas")
# df_all = pd.concat([df.assign(anio=i) for i, df in dfs.items()], ignore_index=True)
